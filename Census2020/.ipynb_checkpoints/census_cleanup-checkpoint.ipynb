# %%
import pandas as pd

# %%
sage = pd.read_csv("ACSDT5Y2020_sexbyage_noerr_clean.csv")

# %%
sage
# Out:
#                  Zip Code      Total     Male Male Under 5 years  \
# 0                   78610        NaN      NaN                NaN
# 1                Estimate     39,498   19,472              1,620
# 2                   78612        NaN      NaN                NaN
# 3                Estimate     16,234    8,178                521
# 4                   78613        NaN      NaN                NaN
# ..                    ...        ...      ...                ...
# 117              Estimate     50,575   25,176              1,950
# 118                 78759        NaN      NaN                NaN
# 119              Estimate     45,901   23,282              1,567
# 120  Travis County, Texas        NaN      NaN                NaN
# 121              Estimate  1,250,884  631,786             39,799
#
#     Male 5 to 9 years Male 10 to 14 years Male 15 to 17 years  \
# 0                 NaN                 NaN                 NaN
# ...

# %%
sage.iloc[0][1:] = sage.iloc[1][1:]

# %%
# Out:
#                  Zip Code      Total     Male Male Under 5 years  \
# 0                   78610     39,498   19,472              1,620
# 1                Estimate     39,498   19,472              1,620
# 2                   78612        NaN      NaN                NaN
# 3                Estimate     16,234    8,178                521
# 4                   78613        NaN      NaN                NaN
# ..                    ...        ...      ...                ...
# 117              Estimate     50,575   25,176              1,950
# 118                 78759        NaN      NaN                NaN
# 119              Estimate     45,901   23,282              1,567
# 120  Travis County, Texas        NaN      NaN                NaN
# 121              Estimate  1,250,884  631,786             39,799
#
#     Male 5 to 9 years Male 10 to 14 years Male 15 to 17 years  \
# 0               2,014               1,431                 823
# ...
