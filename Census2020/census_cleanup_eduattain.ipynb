# %%
import pandas as pd

# %%
df = pd.read_csv("./raw/ACSST5Y2020.S1501_eduattain.csv")

# %%
df
# Out:
#              Label (Grouping)  AGE BY EDUCATIONAL ATTAINMENT  \
# 0                 ZCTA5 78610                            NaN
# 1                       Total                            NaN
# 2                    Estimate                            NaN
# 3             Margin of Error                            NaN
# 4                     Percent                            NaN
# ...                       ...                            ...
# 1154                 Estimate                            NaN
# 1155          Margin of Error                            NaN
# 1156           Percent Female                            NaN
# 1157                 Estimate                            NaN
# 1158          Margin of Error                            NaN
#
#      AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 0                                                   NaN
# 1                                                   NaN
# ...

# %%
df.columns = df.columns.str.replace("!!", " ")
df = df.replace("ZCTA5 ","",regex=True)
df = df.replace("±", "", regex=True)
df = df.rename(columns={"Label (Grouping)": "Zip Code"})

# %%
# Totals
df_total_est = df.copy()
df_total_est_err = df.copy()

for idx in range(0,len(df),19):
    if idx == len(df) - 19:
        df_total_est.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_est.loc[idx + 2,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_total_est_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_est_err.loc[idx + 3,'AGE BY EDUCATIONAL ATTAINMENT':]
        break
    else:
        df_total_est.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_est.loc[idx + 2,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_total_est_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_est_err.loc[idx + 3,'AGE BY EDUCATIONAL ATTAINMENT':]

df_total_est = df_total_est.loc[list(range(0,len(df),19))]
df_total_est_err = df_total_est_err.loc[list(range(0,len(df),19))]

df_total_est = df_total_est.reset_index()
df_total_est_err = df_total_est_err.reset_index()

df_total_est = df_total_est.drop(columns=['index'])
df_total_est_err = df_total_est_err.drop(columns=['index'])

# Percent of population
df_total_percent = df.copy()
df_total_percent_err = df.copy()

for idx in range(0,len(df),19):
    if idx == len(df) - 19:
        df_total_percent.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_percent.loc[idx + 5,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_total_percent_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_percent_err.loc[idx + 6,'AGE BY EDUCATIONAL ATTAINMENT':]
        break
    else:
        df_total_percent.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_percent.loc[idx + 5,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_total_percent_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_total_percent_err.loc[idx + 6,'AGE BY EDUCATIONAL ATTAINMENT':]

df_total_percent = df_total_percent.loc[list(range(0,len(df),19))]
df_total_percent_err = df_total_percent_err.loc[list(range(0,len(df),19))]

df_total_percent = df_total_percent.reset_index()
df_total_percent_err = df_total_percent_err.reset_index()

df_total_percent = df_total_percent.drop(columns=['index'])
df_total_percent_err = df_total_percent_err.drop(columns=['index'])

# %%
# Male
df_male_est = df.copy()
df_male_est_err = df.copy()

for idx in range(0,len(df),19):
    if idx == len(df) - 19:
        df_male_est.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_est.loc[idx + 8,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_male_est_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_est_err.loc[idx + 9,'AGE BY EDUCATIONAL ATTAINMENT':]
        break
    else:
        df_male_est.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_est.loc[idx + 8,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_male_est_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_est_err.loc[idx + 9,'AGE BY EDUCATIONAL ATTAINMENT':]

df_male_est = df_male_est.loc[list(range(0,len(df),19))]
df_male_est_err = df_male_est_err.loc[list(range(0,len(df),19))]

df_male_est = df_male_est.reset_index()
df_male_est_err = df_male_est_err.reset_index()

df_male_est = df_male_est.drop(columns=['index'])
df_male_est_err = df_male_est_err.drop(columns=['index'])

# Percent Male
df_male_percent = df.copy()
df_male_percent_err = df.copy()

for idx in range(0,len(df),19):
    if idx == len(df) - 19:
        df_male_percent.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_percent.loc[idx + 11,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_male_percent_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_percent_err.loc[idx + 12,'AGE BY EDUCATIONAL ATTAINMENT':]
        break
    else:
        df_male_percent.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_percent.loc[idx + 11,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_male_percent_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_male_percent_err.loc[idx + 12,'AGE BY EDUCATIONAL ATTAINMENT':]

df_male_percent = df_male_percent.loc[list(range(0,len(df),19))]
df_male_percent_err = df_male_percent_err.loc[list(range(0,len(df),19))]

df_male_percent = df_male_percent.reset_index()
df_male_percent_err = df_male_percent_err.reset_index()

df_male_percent = df_male_percent.drop(columns=['index'])
df_male_percent_err = df_male_percent_err.drop(columns=['index'])

# %%
# Female
df_fem_est = df.copy()
df_fem_est_err = df.copy()

for idx in range(0,len(df),19):
    if idx == len(df) - 19:
        df_fem_est.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_fem_est.loc[idx + 14,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_fem_est_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_fem_est_err.loc[idx + 15,'AGE BY EDUCATIONAL ATTAINMENT':]
        break
    else:
        df_fem_est.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_fem_est.loc[idx + 14,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_fem_est_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_fem_est_err.loc[idx + 15,'AGE BY EDUCATIONAL ATTAINMENT':]

df_fem_est = df_fem_est.loc[list(range(0,len(df),19))]
df_fem_est_err = df_fem_est_err.loc[list(range(0,len(df),19))]

df_fem_est = df_fem_est.reset_index()
df_fem_est_err = df_fem_est_err.reset_index()

df_fem_est = df_fem_est.drop(columns=['index'])
df_fem_est_err = df_fem_est_err.drop(columns=['index'])

# Percent Female
df_fem_percent = df.copy()
df_fem_percent_err = df.copy()

for idx in range(0,len(df),19):
    if idx == len(df) - 19:
        df_fem_percent.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_fem_percent.loc[idx + 17,'AGE BY EDUCATIONAL ATTAINMENT':]
        df_fem_percent_err.loc[idx,'AGE BY EDUCATIONAL ATTAINMENT':] = df_fem_percent_err.loc[idx + 18,'AGE BY EDUCATIONAL ATTAINMENT':]
        break
    else:
        df_fem_percent.loc[idx] = df_fem_percent.loc[idx + 17]
        df_fem_percent_err.loc[idx] = df_fem_percent_err.loc[idx + 18]

df_fem_percent = df_fem_percent.loc[list(range(0,len(df),19))]
df_fem_percent_err = df_fem_percent_err.loc[list(range(0,len(df),19))]

df_fem_percent = df_fem_percent.reset_index()
df_fem_percent_err = df_fem_percent_err.reset_index()

df_fem_percent = df_fem_percent.drop(columns=['index'])
df_fem_percent_err = df_fem_percent_err.drop(columns=['index'])

# %%
df_total_est.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/total_est.csv')
df_total_est_err.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/total_est_err.csv')
df_total_percent.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/total_percent.csv')
df_total_percent_err.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/total_percent_err.csv')

# %%
df_male_est.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/male_est.csv')
df_male_est_err.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/male_est_err.csv')
df_male_percent.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/male_percent.csv')
df_male_percent_err.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/male_percent_err.csv')

# %%
df_fem_est.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/female_est.csv')
df_fem_est_err.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/female_est_err.csv')
df_fem_percent.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/female_percent.csv')
df_fem_percent_err.to_csv('./clean/ACSST5Y2020.S1501_eduattain_clean/female_percent_err.csv')

# %%
df_total_est_err
# Out:
#                 Zip Code  AGE BY EDUCATIONAL ATTAINMENT  \
# 0                  78610                            NaN
# 1                  78612                            NaN
# 2                  78613                            NaN
# 3                  78615                            NaN
# 4                  78617                            NaN
# ..                   ...                            ...
# 56                 78756                            NaN
# 57                 78757                            NaN
# 58                 78758                            NaN
# 59                 78759                            NaN
# 60  Travis County, Texas                            NaN
#
#    AGE BY EDUCATIONAL ATTAINMENT Population 18 to 24 years  \
# 0                                                 702
# 1                                                 347
# 2                                                 841
# 3                                                  84
# ...
